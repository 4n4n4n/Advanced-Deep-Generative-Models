# %% [markdown]
# # Project 3: Denoising Diffusion (10 pts)
#
# In this project, you will implement a denoising diffusion model to generate MNIST digits. The main idea is that a sufficiently powerful model learns to remove a bit of noise from a noisy sample. By iterating this model on a sample drawn from pure noise, one can generate samples from the training data distribution.
#
# Generating reasonable samples with diffusion requires more advanced architectures than a simple MLP or CNN stack. To let you focus on implementing the core algorithm, we provide you with two model architectures:
# 1. A simple convolutional resnet
# 2. A small U-net variant
#
# The former requires less compute and can get you some results even with CPU training in a few minutes. However, in our experience the resnet model will only generate strokes and blotches without the global structure of a digit because of the limited receptive field of the model. If you have a GPU or a bit more time on your hands, you can change the configuration to train a U-net. This takes roughly 5-10x as long but can yield some actual digits if you train it long enough.
#
# **Note**: There was a crucial typo in one of the formulas on the slides. Make sure to download the most recent slides from moodle!
#
# ## Your task
#
# Complete the missing code. Make sure that all the functions follow the provided specification, i.e. the output of the function exactly matches the description in the docstring.
#
# ## General Remarks
#
# Only functionality in the python files will be graded. Carefully read the method docstrings to understand the task, parameters and what output is expected.
# Fill in the missing code at the markers in `ddpm.py`.
# ```python
# ###########################
# # YOUR CODE HERE
# ###########################
# ```
# Do not add or modify any code at other places in the notebook and python code files except where otherwise explicitly stated.
# After you fill in all the missing code, restart the kernel and re-run all the cells in the notebook.
#
# The following things are **NOT** allowed:
# - Using additional `import` statements
# - Using the `torch.distributions` package
# - Copying / reusing code from other sources (e.g. code by other students)
#
# If you plagiarise even for a single project task, you won't be eligible for the bonus this semester.

# %% [markdown]
# ## Task 1: Beta Schedule (2pt)
#
# Your first task is to implement a beta schedule in the `__init__` method of the DDPM class, i.e. a sequence of non-decreasing $0 < \beta_i < 1, i = 0, \ldots, N - 1$. A reasonable default is a linear increase from `1e-4` to `2e-2` as proposed in the [original DDPM paper](https://arxiv.org/abs/2006.11239). Additionally, you have to compute the derived variables $\alpha$, $\bar{\alpha}$ and $\tilde{\beta}$. Feel free to compute other coefficients for your later computations here but you should implement and use at least these 4.

# %% [markdown]
# ## Task 2: Simplified Loss (2pt)
#
# Here, you have to implement the simplified loss from slide 16 in the method `simplified_loss`.
#
# **Note**: The DDPM implementation works with integer noise levels `n` but the models work best with a normalized noise level between $0$ and $1$. So remember to normalize the noise level before calling the model.

# %% [markdown]
# This already gives us everything we need to train the model. The next two tasks yield support routines for the sampling procedure in the final task.

# %% [markdown]
# ## Task 3: Compute $x_0$ from $z_n$ and $\varepsilon$ (2pt)
#
# Given a sample $z_n$ and (an estimate of) $\varepsilon$, we want to find the $x_0$ that produced $z_n$. This will be necessary to sample $z_{n-1}$ in the sampling procedure.
#
# Implement this computation in `estimate_x0`.

# %% [markdown]
# ## Task 4: Sample from $q_{\varphi(x_0)}(z_{n-1} \mid z_n)$ (2pt)
#
# Given $x_0$ and $z_n$, the method `sample_z_n_previous` should generate a sample from $q_{\varphi(x_0)}(z_{n-1} \mid z_n)$.

# %% [markdown]
# ## Task 5: Iterative Sampling (2pt)
#
# Finally, implement the iterative sampling procedure on slide 18. Remember to use the utility functions from the previous two tasks.

# %% [markdown]
# ## Install required packages
#
# Remove the `--quiet` flag to see installation progress.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: torchvision in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: einops in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (0.8.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (2.2.6)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (3.10.3)
# Requirement already satisfied: notebook in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (7.4.4)
# Requirement already satisfied: typeguard==2.13.3 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (2.13.3)
# Requirement already satisfied: torchtyping==0.1.5 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (0.1.5)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (4.13.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (80.8.0)
# Requirement already satisfied: sympy!=1.13.2,>=1.13.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (2025.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from torchvision->-r requirements.txt (line 2)) (11.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from notebook->-r requirements.txt (line 6)) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from notebook->-r requirements.txt (line 6)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.4 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from notebook->-r requirements.txt (line 6)) (4.4.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from notebook->-r requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from notebook->-r requirements.txt (line 6)) (6.5)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.22.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (26.4.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (2.2.5)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (9.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (7.0.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (2.19.1)
# Requirement already satisfied: stack_data in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jinja2->torch->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (0.25.1)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (4.3.8)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from sympy!=1.13.2,>=1.13.1->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 6)) (2.9.0.20250516)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/dgm/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.5,>=4.4.4->notebook->-r requirements.txt (line 6)) (0.2.3)

# %%
import numpy as np
import torch
from torchvision import datasets, transforms

from ddpm import DDPM
from visualization import visualize_dataset_mnist, visualize_mnist_samples

# %% [markdown]
# ## Select an accelerator (CPU or GPU)
#
# Select an accelerator for this project: If you have a GPU available, it will greatly speed up computations. It should however also be feasible to run this notebook entirely on a CPU.

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f"Using device {device}")

def get_device():
    if torch.backends.mps.is_available():
        return torch.device("mps")
    elif torch.cuda.is_available():
        return torch.device("cuda")   # or "cuda:0"
    else:
        return torch.device("cpu")

device = get_device()
print(f"Using device: {device}")
# Out:
# Using device: mps

# %% [markdown]
# ## Load the MNIST dataset

# %%
batch_size = 128
tfs = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)),
])
train_data = datasets.MNIST("./data", train=True, download=True, transform=tfs)
test_data = datasets.MNIST("./data", train=False, download=True, transform=tfs)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=1, pin_memory=device.type == "cuda")
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False, num_workers=1, pin_memory=device.type == "cuda")

# %% [markdown]
# ## Visualize a few random samples from the dataset

# %%
visualize_dataset_mnist(train_data);

# %% [markdown]
# ## Model Training

# %%
max_epochs = 15
display_step = 100

ddpm = DDPM(N=1000, type="unet", hidden_dim=16, n_layers=2).to(device)
opt = torch.optim.Adam(ddpm.parameters())

# %%
for epoch in range(max_epochs):
    print(f"Epoch {epoch}")
    losses = []
    for ix, (x, y) in enumerate(train_loader):
        x = x.to(device)
        y = y.to(device)

        loss = ddpm.loss(x)
        
        opt.zero_grad()
        loss.backward()
        opt.step()

        losses.append(loss.item())
        if ix % display_step == 0:
            print(f"  loss = {loss.item():.2f}")
    print(f"  => mean(loss) = {np.mean(losses):.2f}")
# Out:
# Epoch 0
#   loss = 28.38
#   loss = 25.76
#   loss = 25.08
#   loss = 23.20
#   loss = 27.77
#   => mean(loss) = 27.81
# Epoch 1
#   loss = 28.77
#   loss = 24.34
#   loss = 31.09
#   loss = 28.83
#   loss = 32.58
#   => mean(loss) = 27.41
# Epoch 2
#   loss = 24.55
#   loss = 25.97
#   loss = 27.98
#   loss = 25.00
#   loss = 28.41
#   => mean(loss) = 27.30

# %% [markdown]
# ## Sampling

# %%
samples = ddpm.sample(20, device)

# %%
visualize_mnist_samples(samples);
